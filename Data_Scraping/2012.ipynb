# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import pandas as pd
import numpy as np

# %%
avg_drivingdistance = pd.read_html('https://www.pgatour.com/content/pgatour/stats/stat.101.y2012.eon.t014.html')
drivingaccuracy = pd.read_html('https://www.pgatour.com/content/pgatour/stats/stat.102.y2012.eon.t014.html')
gir = pd.read_html('https://www.pgatour.com/content/pgatour/stats/stat.103.y2012.eon.t014.html')
scrambling = pd.read_html('https://www.pgatour.com/content/pgatour/stats/stat.130.y2012.eon.t014.html')
sandsaves = pd.read_html('https://www.pgatour.com/content/pgatour/stats/stat.111.y2012.eon.t014.html')
putting_avg = pd.read_html('https://www.pgatour.com/content/pgatour/stats/stat.104.y2012.eon.t014.html')

# %%
df1 = avg_drivingdistance[1][['PLAYER NAME','AVG.']].rename(columns={'AVG.': 'avg_driv_dist'}).set_index('PLAYER NAME')

# %%
df2 = drivingaccuracy[1][['PLAYER NAME','%']].rename(columns={'%': 'driv_acc%'}).set_index('PLAYER NAME')

# %%
df3 = gir[1][['PLAYER NAME','%']].rename(columns={'%': 'gir%'}).set_index('PLAYER NAME')

# %%
df4 = scrambling[1][['PLAYER NAME','%']].rename(columns={'%': 'scrambling%'}).set_index('PLAYER NAME')

# %%
df5 = sandsaves[1][['PLAYER NAME','%']].rename(columns={'%': 'sandsaves'}).set_index('PLAYER NAME')

# %%
df6 = putting_avg[1][['PLAYER NAME','AVG']].rename(columns={'AVG': 'putting_avg'}).set_index('PLAYER NAME')

# %%
leaderboard = pd.read_html('https://www.espn.com/golf/leaderboard/_/tournamentId/1005')[1]
leaderboard['PLAYER'] = leaderboard['PLAYER'].str.replace(r"\(.*\)","").str.replace(r'[^a-zA-Z .]+', '').str.strip()
leaderboard = leaderboard[['PLAYER','TO PAR']].rename(columns={'TO PAR': 'score','PLAYER': 'PLAYER NAME'}).set_index('PLAYER NAME')
leaderboard
# Out:
#                  score
# PLAYER NAME
# Bubba Watson       -10
# Louis Oosthuizen   -10
# Peter Hanson        -8
# Lee Westwood        -8
# Matt Kuchar         -8
# ...                ...
# Craig Stadler      CUT
# Sandy Lyle         CUT
# Mark OMeara         WD
# Jason Day           WD
# Gary Woodland       WD
#
# [96 rows x 1 columns]

# %%
merged_df = pd.concat([df1, df2, df3, df4, df5, df6, leaderboard], axis=1, sort=False)

# %%
merged_df.isnull().sum()
# Out:
# avg_driv_dist    39
# driv_acc%        39
# gir%             39
# scrambling%      39
# sandsaves        39
# putting_avg      39
# score             5
# dtype: int64

# %%
merged_df[pd.isnull(merged_df).any(axis=1)]
# Out:
#                            avg_driv_dist  driv_acc%   gir%  scrambling%  \
# Ángel Cabrera                      281.9      62.50  66.67        50.00
# Thomas Bjørn                       279.9      78.57  54.17        60.61
# Sean O'Hair                        279.4      73.21  56.94        54.84
# Miguel Angel Jiménez               276.4      69.64  55.56        50.00
# Gonzalo Fernandez-Castaño          273.6      67.86  55.56        53.13
# Angel Cabrera                        NaN        NaN    NaN          NaN
# Sean OHair                           NaN        NaN    NaN          NaN
# Thomas Bjrn                          NaN        NaN    NaN          NaN
# Miguel Angel Jimnez                  NaN        NaN    NaN          NaN
# Gonzalo FernndezCastao               NaN        NaN    NaN          NaN
# Kyung Kim                            NaN        NaN    NaN          NaN
# John Senden                          NaN        NaN    NaN          NaN
# Harrison Frazar                      NaN        NaN    NaN          NaN
# Paul Casey                           NaN        NaN    NaN          NaN
# Larry Mize                           NaN        NaN    NaN          NaN
# Tom Watson                           NaN        NaN    NaN          NaN
# Mike Weir                            NaN        NaN    NaN          NaN
# Jose Maria Olazabal                  NaN        NaN    NaN          NaN
# Kyle Stanley                         NaN        NaN    NaN          NaN
# Rory Sabbatini                       NaN        NaN    NaN          NaN
# Bernhard Langer                      NaN        NaN    NaN          NaN
# Robert Garrigus                      NaN        NaN    NaN          NaN
# Ryan Palmer                          NaN        NaN    NaN          NaN
# Chez Reavie                          NaN        NaN    NaN          NaN
# Johnson Wagner                       NaN        NaN    NaN          NaN
# K.J. Choi                            NaN        NaN    NaN          NaN
# Ryo Ishikawa                         NaN        NaN    NaN          NaN
# Bryden MacPherson                    NaN        NaN    NaN          NaN
# Tim Clark                            NaN        NaN    NaN          NaN
# Darren Clarke                        NaN        NaN    NaN          NaN
# Lucas Glover                         NaN        NaN    NaN          NaN
# Ian Woosnam                          NaN        NaN    NaN          NaN
# Mark Wilson                          NaN        NaN    NaN          NaN
# Simon Dyson                          NaN        NaN    NaN          NaN
# Corbin Mills                         NaN        NaN    NaN          NaN
# Alvaro Quiros                        NaN        NaN    NaN          NaN
# Brendan Steele                       NaN        NaN    NaN          NaN
# Randy Lewis                          NaN        NaN    NaN          NaN
# Ben Crenshaw                         NaN        NaN    NaN          NaN
# Craig Stadler                        NaN        NaN    NaN          NaN
# Sandy Lyle                           NaN        NaN    NaN          NaN
# Mark OMeara                          NaN        NaN    NaN          NaN
# Jason Day                            NaN        NaN    NaN          NaN
# Gary Woodland                        NaN        NaN    NaN          NaN
#
#                            sandsaves  putting_avg score
# Ángel Cabrera                  25.00        1.833   NaN
# Thomas Bjørn                   62.50        1.872   NaN
# Sean O'Hair                    25.00        1.756   NaN
# Miguel Angel Jiménez           42.86        1.850   NaN
# Gonzalo Fernandez-Castaño      66.67        1.950   NaN
# Angel Cabrera                    NaN          NaN    +3
# Sean OHair                       NaN          NaN    +3
# Thomas Bjrn                      NaN          NaN    +4
# Miguel Angel Jimnez              NaN          NaN   +10
# Gonzalo FernndezCastao           NaN          NaN   +14
# Kyung Kim                        NaN          NaN   CUT
# John Senden                      NaN          NaN   CUT
# Harrison Frazar                  NaN          NaN   CUT
# Paul Casey                       NaN          NaN   CUT
# Larry Mize                       NaN          NaN   CUT
# Tom Watson                       NaN          NaN   CUT
# Mike Weir                        NaN          NaN   CUT
# Jose Maria Olazabal              NaN          NaN   CUT
# Kyle Stanley                     NaN          NaN   CUT
# Rory Sabbatini                   NaN          NaN   CUT
# Bernhard Langer                  NaN          NaN   CUT
# Robert Garrigus                  NaN          NaN   CUT
# Ryan Palmer                      NaN          NaN   CUT
# Chez Reavie                      NaN          NaN   CUT
# Johnson Wagner                   NaN          NaN   CUT
# K.J. Choi                        NaN          NaN   CUT
# Ryo Ishikawa                     NaN          NaN   CUT
# Bryden MacPherson                NaN          NaN   CUT
# Tim Clark                        NaN          NaN   CUT
# Darren Clarke                    NaN          NaN   CUT
# Lucas Glover                     NaN          NaN   CUT
# Ian Woosnam                      NaN          NaN   CUT
# Mark Wilson                      NaN          NaN   CUT
# Simon Dyson                      NaN          NaN   CUT
# Corbin Mills                     NaN          NaN   CUT
# Alvaro Quiros                    NaN          NaN   CUT
# Fred Couples                273.1      75.00  61.11        60.71      66.67
# Stewart Cink                273.0      85.71  68.06        52.17      42.86
# Graeme McDowell             273.0      76.79  59.72        62.07      33.33
# Bill Haas                   272.8      69.64  63.89        42.31      40.00
# Francesco Molinari          272.4      85.71  75.00        55.56      42.86
# Luke Donald                 272.4      80.36  56.94        58.06      71.43
# Jim Furyk                   272.1      80.36  68.06        47.83      33.33
# Zach Johnson                271.9      83.93  58.33        60.00      25.00
# Steve Stricker              271.1      83.93  56.94        64.52      25.00
# Kelly Kraft                 271.1      67.86  48.61        43.24      55.56
# Kevin Na                    268.1      76.79  58.33        63.33      20.00
# Edoardo Molinari            266.4      73.21  48.61        54.05      75.00
# Scott Verplank              265.3      69.64  56.94        41.94      44.44
# David Toms                  260.3      80.36  54.17        66.67      83.33
#
#                     putting_avg score  year
# Keegan Bradley            1.744    +2  2012
# Ross Fisher               1.904    +7  2012
# Louis Oosthuizen          1.647   -10  2012
# Bubba Watson              1.811   -10  2012
# Paul Lawrie               1.848    +1  2012
# Bo Van Pelt               1.787    -1  2012
# Padraig Harrington        1.762    -4  2012
# Lee Westwood              1.845    -8  2012
# Justin Rose               1.865    -4  2012
# Patrick Cantlay           1.700    +7  2012
# Trevor Immelman           1.875   +13  2012
# Robert Karlsson           1.829    +8  2012
# Henrik Stenson            1.756    +5  2012
# Martin Laird              1.938   +11  2012
# Rory McIlroy              1.778    +5  2012
# Ben Crane                 1.776    -1  2012
# Charles Howell III        1.878     E  2012
# Hideki Matsuyama          1.829    +9  2012
# Brandt Snedeker           1.651     E  2012
# Aaron Baddeley            1.700    +5  2012
# Nick Watney               1.886    +3  2012
# Webb Simpson              1.943    +6  2012
# Hunter Mahan              1.824    -2  2012
# Freddie Jacobson          1.756     E  2012
# Phil Mickelson            1.667    -8  2012
# Scott Stallings           1.796    +2  2012
# Jason Dufner              1.854    +1  2012
# Tiger Woods               1.800    +5  2012
# Vijay Singh               1.911    +2  2012
# Peter Hanson              1.735    -8  2012
# Sangmoon Bae              1.837    +4  2012
# Adam Scott                1.827    -4  2012
# Matt Kuchar               1.828    -8  2012
# Y.E. Yang                 1.886   +11  2012
# Ian Poulter               1.721    -5  2012
# Geoff Ogilvy              1.848     E  2012
# Sergio Garcia             1.705    -2  2012
# Anders Hansen             1.854    +1  2012
# Jonathan Byrd             1.805    +2  2012
# Rickie Fowler             1.841    +2  2012
# Charl Schwartzel          1.857    +8  2012
# Martin Kaymer             1.795    +6  2012
# Kevin Chappell            1.864    +6  2012
# Fred Couples              1.727    -2  2012
# Stewart Cink              1.878    +8  2012
# Graeme McDowell           1.814    -2  2012
# Bill Haas                 1.848    +4  2012
# Francesco Molinari        1.889     E  2012
# Luke Donald               1.805    +3  2012
# Jim Furyk                 1.714    -3  2012
# Zach Johnson              1.810    +3  2012
# Steve Stricker            1.927    +7  2012
# Kelly Kraft               1.800   +18  2012
# Kevin Na                  1.762    -2  2012
# Edoardo Molinari          1.857   +11  2012
# Scott Verplank            1.756    +9  2012
# David Toms                1.923    +8  2012

# %%
merged_df.to_csv('2012.csv')
